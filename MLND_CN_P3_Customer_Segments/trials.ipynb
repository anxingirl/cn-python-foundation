# %%
# %matplotlib inline
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(10 * rng.rand(160, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 2 * (0.5 - rng.rand(32)) # 每五个点增加一次噪音

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_3 = DecisionTreeRegressor(max_depth=8)
regr_1.fit(X, y)
regr_2.fit(X, y)
regr_3.fit(X, y)

# Predict
X_test = np.arange(0.0, 10.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)
y_3 = regr_3.predict(X_test)

# Plot the results
plt.figure()
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue",label="max_depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.plot(X_test, y_3, color="r", label="max_depth=8", linewidth=2)
plt.xlabel("data")
#plt.ylabel("target")
#plt.title("Decision Tree Regression")
plt.legend()
plt.show()

# %%
type(X)
# Out:
# numpy.ndarray

# %%
type(X_test)
# Out:
# numpy.ndarray

# %%
len(X)
# Out:
# 160

# %%
len(X_test)
# Out:
# 1000

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
#plt.axis([0, 6, 0, 20])
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
#plt.axis([0, 6, 0, 20])
plt.show()

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

region = ['Azerbaijan','Bahamas', 'Bangladesh', 'Belize', 'Bhutan',
          'Cambodia', 'Cameroon', 'Cape Verde', 'Chile', 'China']   #10个

kind = ['Afforestation & reforestation', 'Biofuels', 'Biogas', 'Biomass', 'Cement']   #5个

np.random.seed(20180316)
arr_region = np.random.choice(region, size=(200,))
list_region = list(arr_region)

arr_kind = np.random.choice(kind, size=(200,))
list_kind = list(arr_kind)

values = np.random.randint(100, 200, 200)
list_values = list(values)

df = pd.DataFrame({'region':list_region,'kind': list_kind,'values':list_values})
df
# Out:
#                               kind      region  values
# 0                           Cement    Cameroon     140
# 1    Afforestation & reforestation      Bhutan     178
# 2                         Biofuels       China     161
# 3    Afforestation & reforestation    Cambodia     100
# 4                         Biofuels     Bahamas     129
# 5                           Cement  Azerbaijan     121
# 6    Afforestation & reforestation       China     142
# 7    Afforestation & reforestation  Azerbaijan     157
# 8    Afforestation & reforestation     Bahamas     134
# 9                           Cement      Belize     125
# 10                          Biogas    Cameroon     177
# 11                         Biomass  Bangladesh     163
# 12                          Biogas  Bangladesh     127
# 13                          Cement  Bangladesh     128
# 14                          Cement     Bahamas     181
# 15                         Biomass    Cambodia     105
# 16                          Cement    Cameroon     193
# 17                          Cement  Cape Verde     160
# 18                        Biofuels     Bahamas     181
# 19                         Biomass      Belize     117
# 20                          Biogas     Bahamas     165
# 21                          Biogas  Cape Verde     183
# 22                         Biomass     Bahamas     153
# 23                          Cement    Cambodia     134
# 24                         Biomass      Bhutan     199
# 25                          Biogas      Belize     123
# 26                          Cement      Belize     173
# 27                          Biogas    Cameroon     182
# 28                        Biofuels  Azerbaijan     177
# 29   Afforestation & reforestation     Bahamas     109
# ..                             ...         ...     ...
# 170                         Cement    Cambodia     163
# 171                        Biomass    Cambodia     107
# 172                        Biomass      Bhutan     185
# 173                         Cement      Belize     151
# 174                         Cement    Cameroon     183
# 175                       Biofuels  Bangladesh     192
# 176                         Cement      Bhutan     133
# 177                       Biofuels     Bahamas     126
# 178                        Biomass  Azerbaijan     179
# 179                         Cement  Bangladesh     127
# 180                        Biomass       China     181
# 181                         Cement    Cameroon     138
# 182                       Biofuels       Chile     175
# 183                         Biogas  Cape Verde     176
# 184                         Cement    Cambodia     192
# 185  Afforestation & reforestation  Cape Verde     155
# 186                       Biofuels  Cape Verde     188
# 187                         Biogas    Cambodia     139
# 188                         Biogas    Cambodia     191
# 189                         Cement    Cameroon     135
# 190                         Biogas  Cape Verde     134
# 191                         Biogas  Bangladesh     174
# 192                        Biomass      Belize     174
# 193                        Biomass    Cameroon     153
# 194                        Biomass  Azerbaijan     177
# 195                       Biofuels      Belize     119
# 196                       Biofuels       China     183
# 197                         Biogas    Cameroon     114
# 198  Afforestation & reforestation       China     143
# 199  Afforestation & reforestation      Belize     149
#
# [200 rows x 3 columns]

# %%
pt = df.pivot_table(index='kind', columns='region', values='values', aggfunc=np.sum)
pt.head()
# Out:
# region                         Azerbaijan  Bahamas  Bangladesh  Belize  \
# kind
# Afforestation & reforestation         568      571         183     617
# Biofuels                              515      903         410     471
# Biogas                                499      614         976     437
# Biomass                               834      153         317     904
# Cement                                431      549         469     610
#
# region                         Bhutan  Cambodia  Cameroon  Cape Verde  Chile  \
# kind
# Afforestation & reforestation    1161       939       251         471    225
# Biofuels                          325       832       636        1060    313
# Biogas                            374       990       888        1276    715
# Biomass                           739       532       153         155    164
# Cement                            835       974      1077        1103    194
#
# region                         China
# kind
# Afforestation & reforestation    608
# Biofuels                         782
# Biogas                           130
# Biomass                          749
# Cement                           747

# %%
import matplotlib.pyplot as plt
% matplotlib inline

f, (ax1,ax2) = plt.subplots(figsize = (6,4),nrows=2)

# cmap用cubehelix map颜色
cmap = sns.cubehelix_palette(start = 1.5, rot = 3, gamma=0.8, as_cmap = True)
sns.heatmap(pt, linewidths = 0.1, ax = ax1, vmax=900, vmin=0, cmap=cmap)
ax1.set_title('cubehelix map')
ax1.set_xlabel('')
ax1.set_xticklabels([]) #设置x轴图例为空值
ax1.set_ylabel('kind')

# cmap用matplotlib colormap
sns.heatmap(pt, linewidths = 0.05, ax = ax2, vmax=900, vmin=0, cmap='rainbow') 
# rainbow为 matplotlib 的colormap名称
ax2.set_title('matplotlib colormap')
ax2.set_xlabel('region')
ax2.set_ylabel('kind')
# Out:
# Text(33,0.5,'kind')
